# %%
#importing libraries
import tensorflow 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Convolution2D, MaxPooling2D
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow.keras.utils as tfk
import cv2
import tensorflow as tf

# %%
data = pd.read_csv("/kaggle/input/digit-recognizer/train.csv")
data.head()

# %%
data.shape

# %%
#reshaping into 28X28 array
f=data.iloc[15,1:].values.reshape(28,28)
plt.imshow(f)

# %%
# img = cv2.imread('/kaggle/input/imagedata/number2.png',0)
img = cv2.imread('/kaggle/input/numbers/9.png',0)
rows,cols = img.shape
pixel_data = []
for i in range(rows):
  for j in range(cols):
     k = img[i,j]
#      if k > 0:
#         k=1
     pixel_data.append(k)

# %%
pixel_data = pd.Series(pixel_data)
pixel_data

# %%
#Storing Pixel array in form length width and channel in df_x
df_x = data.iloc[:,1:].values.reshape(len(data),28,28,1).astype('float32')

#Storing the labels in y
y = data.iloc[:,0].values

# %%
df_y = tfk.to_categorical(y, num_classes=10, dtype='int64')
df_x = np.array(df_x)
df_y = np.array(df_y)

# %%
#test train split

x_train, x_test, y_train, y_test = train_test_split(df_x,df_y,test_size=0.2,random_state=4)

# %%
#CNN model
model = Sequential()
model.add(Convolution2D(100,3,data_format='channels_last',activation='relu',input_shape=(28,28,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(1000))
# model.add(Dropout(0.5))
model.add(Dense(10))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.summary()

# %%
#fitting it with just 100 images for testing 

model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=1,verbose=2)

# %%
model.predict(x_test)

# %%
var = data.iloc[50:60:,1:].values.reshape(10,28,28,1).astype('float32')
model.predict_classes(var)

# %%
data.iloc[50,1:]

# %% [markdown]
# # Output

# %%
var = pixel_data.values.reshape(1,28,28,1).astype('float32')
model.predict_classes(var)

# %%
# save model and architecture to single file
model.save("model.h5")

# %%
model1 = tf.keras.models.load_model('/kaggle/working/model.h5')

# %%
model1.predict_classes(var)
